# %%
import numpy as np
import matplotlib.pyplot as plt
v=np.array([-2,-0])
plt.plot([0,v[0]],[0,v[1]])
v=np.array([1,2])
plt.plot([0,v[0]],[0,v[1]])
v=np.array([-1,2])
plt.plot([0,v[0]],[0,v[1]])
v=np.array([2,0])
plt.plot([0,v[0]],[0,v[1]])
v=np.array([-1,-2])
plt.plot([0,v[0]],[0,v[1]])
v=np.array([1,-2])
plt.plot([0,v[0]],[0,v[1]])
v=np.array([0,2])
plt.plot([0,v[0]],[0,v[1]])
v=np.array([0,-2])
plt.plot([0,v[0]],[0,v[1]])
plt.axis([-3,3,-3,3])
# Out:
# (-3.0, 3.0, -3.0, 3.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
v=np.array([0,2])
plt.plot([0,v[0]],[0,v[1]])
v=np.array([2,2])
plt.plot([2,2])
v=np.array([1,1])
plt.plot([1,1])
v=np.array([3,2])


plt.plot([-1,-1],[-2,4])
plt.plot([12.70,12.70],[-2,4])

plt.plot([3,3],[4,4])

plt.plot([1,2],[0,2])
plt.plot([2,3],[2,0])
plt.plot([1.5,2.50],[1,1])
plt.plot([4,5],[2,2])
plt.plot([5,4],[2,0])
plt.plot([5,4],[0,0])

plt.plot([5.50,6],[0,2])
plt.plot([6,6.50],[2,0])
plt.plot([5.70,6.30],[1,1])
plt.plot([6.90,6.90],[0,2])
plt.plot([6.90,7.40],[0,0])
plt.plot([7.80,7.80],[0,2])
plt.plot([7.80,8.60],[0,0])
plt.plot([8.60,8.60],[0,2])
plt.plot([8.90,8.90],[0,2])
plt.plot([8.90,9.30],[0,0])
plt.plot([9.60,9.60],[0,2])
plt.plot([9.60,10],[0,0])
plt.plot([10.20,10.80],[0,2])
plt.plot([10.90,11.30],[2,0])
plt.plot([10.40,11],[1,1])
plt.plot([11.55,11.55],[0,2])
plt.plot([12.40,12.40],[0,2])
plt.plot([11.60,12.40],[1,1])
plt.axis([-13,13,-13,13])
# Out:
# (-13.0, 13.0, -13.0, 13.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
v=np.array([2,4])
plt.plot([0,v[0]],[0,v[1]])
plt.axis([-3,3,-3,3])
# Out:
# (-3.0, 3.0, -3.0, 3.0)
